# %% [markdown]
# ![Pink and Black Internship Application LinkedIn Banner.jpg](attachment:178aa370-3be8-49fb-92b7-6e7ae79218cc.jpg)

# %% [markdown]
# <blockquote>📌 In CIFAR-10, there are 60000, 32x32 color images from these 10 classes, with 6000 images from each class. The training dataset contains 50,000 training images and the test dataset contains 10000 test images.
# <br><br>
# The dataset images are of color images with a (32 x 32) resolution. All the images in the dataset are of shape (32,32,3) where 3 represents the number of channels i.e R-G-B (Red,Green & Blue).
# </blockquote>

# %% [markdown]
# ### <h3 style="background-color:#f78e77;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Importing Libraries & Packages 📚 </centre></strong></h3>

# %%
# getting started with the model 
# importing required libraries/packages 

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
import tensorflow as tf

from tensorflow import keras
from keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score

import warnings 
warnings.filterwarnings('ignore')

print("Tensorflow version:",tf.__version__)
print("Keras version:",keras.__version__)
# Out:
# Tensorflow version: 2.4.1
# Keras version: 2.4.0

# %% [markdown]
# ### <h3 style="background-color:#f78e77;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>✏️ Importing & Reading the dataset 📝 </centre></strong></h3>

# %% [markdown]
# <blockquote>📌 The Keras dataset module already comes with the CIFAR-10 dataset. So,we can directly import it using the ‘keras.datasets’ command.</blockquote>

# %%
# Importing the CIFAR-10 dataset from Keras 
from tensorflow.keras.datasets import cifar10
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# %%
print('X_train Shape: {}'.format(X_train.shape))
print('X_test Shape: {}'.format(X_test.shape))
print('Y_train Shape: {}'.format(Y_train.shape))
print('Y_test Shape: {}'.format(Y_test.shape))
# Out:
# X_train Shape: (50000, 32, 32, 3)
# X_test Shape: (10000, 32, 32, 3)
# Y_train Shape: (50000, 1)
# Y_test Shape: (10000, 1)

# %%
plt.figure()
plt.imshow(X_train[12])
plt.colorbar()

# %% [markdown]
# ### <h3 style="background-color:#f78e77;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Normalizing and One-Hot Encoding 🗝</centre></strong></h3>

# %% [markdown]
# <blockquote>📌 We have to normalize the data in order to reduce the pixel values. Currently, all the image pixels are in a range from 0–255, and we want the values in the range of 0 and 1. So we can either divide all the pixel values by 255.0 or use the ‘normalize’ command from keras library. As CIFAR-10 has 10 classes, we are using the ‘to_categorical()’ method to one-hot encode the data.</blockquote>

# %%
# Normalizing
X_train = X_train/255
X_test = X_test/255

# One-Hot-Encoding
Y_train_en = to_categorical(Y_train,10)
Y_test_en = to_categorical(Y_test,10)

# %%
# Visualizing the data 
for i in range(1,31):
  plt.subplot(2, 15, i)
  plt.imshow(X_train[i])

# %% [markdown]
# ### <h3 style="background-color:#f78e77;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>🔨 Building Base Model 🔧</centre></strong></h3>

# %% [markdown]
# <blockquote>📌 Now it’s time to build our model. We are going to use a Convolution Neural Network (CNN) to train our model.</blockquote>

# %%
# Base Model
model = Sequential()
model.add(Conv2D(32,(4,4),input_shape = (32,32,3),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(32,(4,4),input_shape = (32,32,3),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(128, activation ='relu'))
model.add(Dense(10, activation ='softmax'))
model.compile(loss ='categorical_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.summary()
history = model.fit(X_train, Y_train_en, epochs = 20, verbose=1,validation_data=(X_test,Y_test_en))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 29, 29, 32)        1568
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        16416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               102528
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 121,802
# Trainable params: 121,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.7003 - accuracy: 0.3805 - val_loss: 1.2707 - val_accuracy: 0.5486
# Epoch 2/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 1.1951 - accuracy: 0.5770 - val_loss: 1.0833 - val_accuracy: 0.6176
# Epoch 3/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.0392 - accuracy: 0.6370 - val_loss: 1.0156 - val_accuracy: 0.6355
# Epoch 4/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.9360 - accuracy: 0.6754 - val_loss: 1.0125 - val_accuracy: 0.6427
# Epoch 5/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.8426 - accuracy: 0.7056 - val_loss: 0.9604 - val_accuracy: 0.6625
# Epoch 6/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.7864 - accuracy: 0.7269 - val_loss: 0.9219 - val_accuracy: 0.6806
# Epoch 7/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.7268 - accuracy: 0.7473 - val_loss: 0.9626 - val_accuracy: 0.6709
# Epoch 8/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.6877 - accuracy: 0.7573 - val_loss: 0.9631 - val_accuracy: 0.6749
# Epoch 9/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.6337 - accuracy: 0.7754 - val_loss: 0.9534 - val_accuracy: 0.6775
# Epoch 10/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.5871 - accuracy: 0.7924 - val_loss: 0.9565 - val_accuracy: 0.6832
# Epoch 11/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.5561 - accuracy: 0.8042 - val_loss: 0.9973 - val_accuracy: 0.6849
# Epoch 12/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.5157 - accuracy: 0.8183 - val_loss: 1.0238 - val_accuracy: 0.6748
# Epoch 13/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.4731 - accuracy: 0.8305 - val_loss: 1.0543 - val_accuracy: 0.6819
# Epoch 14/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.4475 - accuracy: 0.8411 - val_loss: 1.1363 - val_accuracy: 0.6692
# Epoch 15/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.4178 - accuracy: 0.8529 - val_loss: 1.1309 - val_accuracy: 0.6739
# Epoch 16/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.3754 - accuracy: 0.8678 - val_loss: 1.1832 - val_accuracy: 0.6714
# Epoch 17/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.3506 - accuracy: 0.8768 - val_loss: 1.2354 - val_accuracy: 0.6706
# Epoch 18/20
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.3244 - accuracy: 0.8850 - val_loss: 1.3310 - val_accuracy: 0.6631
# Epoch 19/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.3067 - accuracy: 0.8933 - val_loss: 1.3601 - val_accuracy: 0.6695
# Epoch 20/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.2859 - accuracy: 0.9005 - val_loss: 1.4004 - val_accuracy: 0.6660

# %%
evaluation = model.evaluate(X_test, Y_test_en)
print('Test Accuracy of Base Model: {}'.format(evaluation[1]))
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.4004 - accuracy: 0.6660
# Test Accuracy of Base Model: 0.6660000085830688

# %%
def plotloss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.plot(history.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()    
plotloss(history)

# %% [markdown]
# <blockquote>📌 After running our base model with 20 Epochs, we are getting 90.05% training accuracy and 66.60% test accuracy which is good but as we can see the validation loss is continuously increasing from the first epoch till the last epoch i.e our base model is overfitting.
# <br><br>
# We can achieve this by adding a few dropout layers in our model. Now we are building our model by dropping 25% of units.</blockquote>

# %% [markdown]
# ### <h3 style="background-color:#f78e77;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Model-1 with Dropouts 🛠</centre></strong></h3>

# %%
# Model_1 with Dropouts
model_1 = Sequential()
model_1.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_1.add(MaxPooling2D(pool_size=(2,2)))
model_1.add(Dropout(0.5)) 
model_1.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_1.add(MaxPooling2D(pool_size=(2,2)))
model_1.add(Dropout(0.25))
model_1.add(Flatten())
model_1.add(Dense(256,activation='relu'))
model_1.add(Dense(10,activation='softmax'))
model_1.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_1.summary()
history_1 = model_1.fit(X_train, Y_train_en, epochs = 30, verbose=1, validation_data=(X_test,Y_test_en))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 29, 29, 64)        3136
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        65600
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 481,162
# Trainable params: 481,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.7826 - accuracy: 0.3439 - val_loss: 1.2778 - val_accuracy: 0.5434
# Epoch 2/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.2924 - accuracy: 0.5385 - val_loss: 1.1646 - val_accuracy: 0.5939
# Epoch 3/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.1540 - accuracy: 0.5893 - val_loss: 1.0873 - val_accuracy: 0.6061
# Epoch 4/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.0706 - accuracy: 0.6236 - val_loss: 0.9920 - val_accuracy: 0.6554
# Epoch 5/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.9826 - accuracy: 0.6515 - val_loss: 1.0229 - val_accuracy: 0.6458
# Epoch 6/30
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.9246 - accuracy: 0.6749 - val_loss: 0.9352 - val_accuracy: 0.6753
# Epoch 7/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.8789 - accuracy: 0.6861 - val_loss: 0.9676 - val_accuracy: 0.6677
# Epoch 8/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.8438 - accuracy: 0.7034 - val_loss: 0.9020 - val_accuracy: 0.6914
# Epoch 9/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.7951 - accuracy: 0.7210 - val_loss: 0.9982 - val_accuracy: 0.6609
# Epoch 10/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.7698 - accuracy: 0.7292 - val_loss: 0.8819 - val_accuracy: 0.6998
# Epoch 11/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.7413 - accuracy: 0.7385 - val_loss: 0.8884 - val_accuracy: 0.6980
# Epoch 12/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.7220 - accuracy: 0.7440 - val_loss: 0.8976 - val_accuracy: 0.6947
# Epoch 13/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.6963 - accuracy: 0.7563 - val_loss: 0.9636 - val_accuracy: 0.6766
# Epoch 14/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.6731 - accuracy: 0.7623 - val_loss: 0.8805 - val_accuracy: 0.7028
# Epoch 15/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.6402 - accuracy: 0.7731 - val_loss: 0.8939 - val_accuracy: 0.7029
# Epoch 16/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.6240 - accuracy: 0.7786 - val_loss: 0.9052 - val_accuracy: 0.7010
# Epoch 17/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.6166 - accuracy: 0.7818 - val_loss: 0.9310 - val_accuracy: 0.6970
# Epoch 18/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5999 - accuracy: 0.7888 - val_loss: 0.9279 - val_accuracy: 0.6998
# Epoch 19/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5752 - accuracy: 0.7922 - val_loss: 0.9444 - val_accuracy: 0.6967
# Epoch 20/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5758 - accuracy: 0.7982 - val_loss: 0.9269 - val_accuracy: 0.6981
# Epoch 21/30
# 1563/1563 [==============================] - 70s 44ms/step - loss: 0.5624 - accuracy: 0.8017 - val_loss: 0.9339 - val_accuracy: 0.6995
# Epoch 22/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5387 - accuracy: 0.8099 - val_loss: 0.9438 - val_accuracy: 0.7011
# Epoch 23/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5393 - accuracy: 0.8092 - val_loss: 0.9831 - val_accuracy: 0.6994
# Epoch 24/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5234 - accuracy: 0.8145 - val_loss: 0.9576 - val_accuracy: 0.7065
# Epoch 25/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5181 - accuracy: 0.8186 - val_loss: 0.9583 - val_accuracy: 0.7101
# Epoch 26/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.5070 - accuracy: 0.8211 - val_loss: 0.9265 - val_accuracy: 0.7100
# Epoch 27/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.4947 - accuracy: 0.8238 - val_loss: 0.9419 - val_accuracy: 0.7102
# Epoch 28/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.4858 - accuracy: 0.8298 - val_loss: 0.9771 - val_accuracy: 0.7064
# Epoch 29/30
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.4841 - accuracy: 0.8273 - val_loss: 0.9783 - val_accuracy: 0.7068
# Epoch 30/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.4868 - accuracy: 0.8282 - val_loss: 0.9781 - val_accuracy: 0.7097

# %%
evaluation = model_1.evaluate(X_test, Y_test_en)
print('Test Accuracy of Model_1(with Dropouts): {}'.format(evaluation[1]))
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.9781 - accuracy: 0.7097
# Test Accuracy of Model_1(with Dropouts): 0.7096999883651733

# %%
def plotloss(history_1):
    plt.plot(history_1.history['loss'])
    plt.plot(history_1.history['val_loss'])
    plt.plot(history_1.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()    
plotloss(history_1)

# %% [markdown]
# <blockquote>📌 After running our model_1 with 30 Epochs, we can see that the validation accuracy has improved from 66.60% to 70.97% due to reduction in our model’s validation loss from 1.4004 to 0.9781.
# <br><br>
# We will continue to train our model by increasing the number of epochs and by adding more filters.</blockquote>

# %% [markdown]
# ### <h3 style="background-color:#f78e77;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Model-2 with more filters 🛠</centre></strong></h3>

# %%
# Model_2 with more filters
model_2 = Sequential()
model_2.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2)))
model_2.add(Dropout(0.4)) 
model_2.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2)))
model_2.add(Dropout(0.4))
model_2.add(Flatten())
model_2.add(Dense(1024,activation='relu'))
model_2.add(Dense(1024,activation='relu'))
model_2.add(Dense(units =10  , activation = 'softmax'))
model_2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_2.summary()
history_2 = model_2.fit(X_train, Y_train_en, epochs = 50, verbose=1, validation_data=(X_test,Y_test_en))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 29, 29, 64)        3136
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 26, 26, 64)        65600
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 10, 10, 128)       131200
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 128)         262272
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1180672
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,702,730
# Trainable params: 2,702,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#
# Epoch 42/50
# 1563/1563 [==============================] - 346s 221ms/step - loss: 0.6617 - accuracy: 0.7704 - val_loss: 0.7911 - val_accuracy: 0.7372
# Epoch 43/50
# 1563/1563 [==============================] - 344s 220ms/step - loss: 0.6732 - accuracy: 0.7682 - val_loss: 0.7920 - val_accuracy: 0.7374
# Epoch 44/50
# 1563/1563 [==============================] - 345s 221ms/step - loss: 0.6584 - accuracy: 0.7743 - val_loss: 0.7998 - val_accuracy: 0.7313
# Epoch 45/50
# 1563/1563 [==============================] - 346s 221ms/step - loss: 0.6471 - accuracy: 0.7780 - val_loss: 0.8459 - val_accuracy: 0.7266
# Epoch 46/50
# 1563/1563 [==============================] - 345s 221ms/step - loss: 0.6530 - accuracy: 0.7744 - val_loss: 0.7756 - val_accuracy: 0.7419
# Epoch 47/50
# 1563/1563 [==============================] - 344s 220ms/step - loss: 0.6457 - accuracy: 0.7772 - val_loss: 0.7692 - val_accuracy: 0.7467
# Epoch 48/50
# 1563/1563 [==============================] - 344s 220ms/step - loss: 0.6366 - accuracy: 0.7801 - val_loss: 0.7862 - val_accuracy: 0.7412
# Epoch 49/50
# 1563/1563 [==============================] - 344s 220ms/step - loss: 0.6286 - accuracy: 0.7815 - val_loss: 0.7770 - val_accuracy: 0.7501
# Epoch 50/50
# 1563/1563 [==============================] - 346s 221ms/step - loss: 0.6253 - accuracy: 0.7848 - val_loss: 0.7735 - val_accuracy: 0.7422

# %%
evaluation = model_2.evaluate(X_test, Y_test_en)
print('Test Accuracy of Model_2(with more  filters): {}'.format(evaluation[1]))
# Out:
# 313/313 [==============================] - 14s 43ms/step - loss: 0.7735 - accuracy: 0.7422
# Test Accuracy of Model_2(with more  filters): 0.7422000169754028

# %%
def plotloss(history_2):
    plt.plot(history_2.history['loss'])
    plt.plot(history_2.history['val_loss'])
    plt.plot(history_2.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()    
plotloss(history_2)

# %% [markdown]
# <blockquote>📌 After running our model_2 with 50 Epochs, we can see that the validation accuracy has further improved from 70.97% to 74.22%
# <br><br>
# We will continue to train our model by adding Batch Normalization.
# </blockquote>

# %% [markdown]
# ### <h3 style="background-color:#f78e77;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Model-3 with Batch Normalization 🛠</centre></strong></h3>

# %%
# Model_3 with Batch Normalization
model_3 = Sequential()
model_3.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(MaxPooling2D(pool_size=(2,2)))
model_3.add(Dropout(0.2))
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(MaxPooling2D(pool_size=(2,2)))
model_3.add(Dropout(0.25))
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(MaxPooling2D(pool_size=(2,2)))
model_3.add(Dropout(0.35))
model_3.add(Flatten())
model_3.add(Dense(256, activation='relu'))
model_3.add(BatchNormalization())
model_3.add(Dropout(0.5))
model_3.add(Dense(10, activation='softmax'))
model_3.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_3.summary()
history_3 = model_3.fit(X_train, Y_train_en, epochs = 10, verbose = 1, validation_data = (X_test, Y_test_en))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        3136
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        65600
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 128)       131200
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 128)       262272
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         262272
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 128)         262272
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               524544
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,517,450
# Trainable params: 1,515,658
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 888s 567ms/step - loss: 2.0024 - accuracy: 0.3641 - val_loss: 1.3876 - val_accuracy: 0.5284
# Epoch 2/10
# 1563/1563 [==============================] - 886s 567ms/step - loss: 1.0055 - accuracy: 0.6455 - val_loss: 0.8382 - val_accuracy: 0.7050
# Epoch 3/10
# 1563/1563 [==============================] - 884s 566ms/step - loss: 0.7672 - accuracy: 0.7353 - val_loss: 0.8862 - val_accuracy: 0.7033
# Epoch 4/10
# 1563/1563 [==============================] - 887s 568ms/step - loss: 0.6399 - accuracy: 0.7819 - val_loss: 2.7321 - val_accuracy: 0.3549
# Epoch 5/10
# 1563/1563 [==============================] - 884s 565ms/step - loss: 0.5556 - accuracy: 0.8120 - val_loss: 0.6667 - val_accuracy: 0.7728
# Epoch 6/10
# 1563/1563 [==============================] - 884s 566ms/step - loss: 0.4879 - accuracy: 0.8336 - val_loss: 0.5123 - val_accuracy: 0.8247
# Epoch 7/10
# 1563/1563 [==============================] - 883s 565ms/step - loss: 0.4133 - accuracy: 0.8584 - val_loss: 0.4914 - val_accuracy: 0.8340
# Epoch 8/10
# 1563/1563 [==============================] - 882s 564ms/step - loss: 0.3713 - accuracy: 0.8755 - val_loss: 0.5303 - val_accuracy: 0.8262
# Epoch 9/10
# 1563/1563 [==============================] - 877s 561ms/step - loss: 0.3258 - accuracy: 0.8901 - val_loss: 0.5960 - val_accuracy: 0.8165
# Epoch 10/10
# 1563/1563 [==============================] - 878s 562ms/step - loss: 0.2999 - accuracy: 0.8934 - val_loss: 0.4881 - val_accuracy: 0.8469

# %%
evaluation = model_3.evaluate(X_test, Y_test_en)
print('Test Accuracy of Model_3 (with Batch Normalization): {}'.format(evaluation[1]))
# Out:
# 313/313 [==============================] - 35s 110ms/step - loss: 0.4881 - accuracy: 0.8469
# Test Accuracy of Model_3 (with Batch Normalization): 0.8468999862670898

# %%
def plotloss(history_3):
    plt.plot(history_3.history['loss'])
    plt.plot(history_3.history['val_loss'])
    plt.plot(history_3.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()    
plotloss(history_3)

# %% [markdown]
# <blockquote>📌 After running our model_3 with Batch Normalization, we can see that the validation accuracy has further improved from 74.22% to 84.68%
# </blockquote>

# %% [markdown]
# 📌 Details of the model setup and the results are discussed in my article https://devashree-madhugiri.medium.com/using-cnn-for-image-classification-on-cifar-10-dataset-7803d9f3b983 published on Medium.
